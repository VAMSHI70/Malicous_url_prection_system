# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:/Users/vamshi/Desktop/LEARNING/SIH/dataset/output.xlsx')

# %%
df
# Out:
#         type  use_of_ip  abnormal_url  google_index  count.  count-www  \
# 0          3          0             0             1       2          0
# 1          0          0             0             1       2          0
# 2          0          0             0             1       2          0
# 3          1          0             1             1       3          1
# 4          1          0             1             1       2          0
# ...      ...        ...           ...           ...     ...        ...
# 651186     3          0             0             1       3          0
# 651187     3          0             0             1       2          0
# 651188     3          0             0             1       2          1
# 651189     3          0             0             1       2          0
# 651190     3          0             0             1       2          1
#
#         count@  count_dir  count_embed_domian  short_url  ...  count?  count-  \
# ...

# %%
x=df.drop(['type'], axis=1)
y=df['type']

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100,max_features='sqrt')
rf.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
import pickle
import os
rf_path=os.path.join(r'C:/Users/vamshi/Desktop/LEARNING/SIH/models','rf.pkl')
with open(rf_path,'wb') as rf_file:
    pickle.dump(rf,rf_file)
